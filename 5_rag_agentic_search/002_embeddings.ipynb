# %%
# Install dependencies
# !uv pip install --upgrade voyageai numpy
# Out:
# Using Python 3.14.3 environment at: /Users/jyang/Desktop/development/anthropic/anthropic-claude-api/.venv
# Checked 2 packages in 22ms

# %%
# Client Setup
from dotenv import load_dotenv
import voyageai

load_dotenv()

client = voyageai.Client()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Client Setup
#       2 from dotenv import load_dotenv
# ----> 3 import voyageai
#       4
#       5 load_dotenv()
#       6
#
# File ~/Desktop/development/anthropic/anthropic-claude-api/.venv/lib/python3.14/site-packages/voyageai/__init__.py:29
#      22 from voyageai.api_resources import (
#      23     ContextualizedEmbedding,
#      24     Embedding,
#      25     MultimodalEmbedding,
#      26     Reranking,
#      27 )
#      28 from voyageai.chunking import default_chunk_fn
# ---> 29 from voyageai.client import Client
#      30 from voyageai.client_async import AsyncClient
#      31 from voyageai.embeddings_utils import (
#      32     aget_embedding,
#      33     aget_embeddings,
#      34     get_embedding,
#      35     get_embeddings,
#      36 )
#
# File ~/Desktop/development/anthropic/anthropic-claude-api/.venv/lib/python3.14/site-packages/voyageai/client.py:14
#      12 import voyageai
#      13 import voyageai.error as error
# ---> 14 from voyageai._base import _BaseClient
#      15 from voyageai.chunking import apply_chunking
#      16 from voyageai.object import (
#      17     ContextualizedEmbeddingsObject,
#      18     EmbeddingsObject,
#      19     MultimodalEmbeddingsObject,
#      20     RerankingObject,
#      21 )
#
# File ~/Desktop/development/anthropic/anthropic-claude-api/.venv/lib/python3.14/site-packages/voyageai/_base.py:13
#      10 from huggingface_hub import hf_hub_download
#      12 import voyageai
# ---> 13 from voyageai.object import EmbeddingsObject, RerankingObject
#      14 from voyageai.object.contextualized_embeddings import ContextualizedEmbeddingsObject
#      15 from voyageai.object.multimodal_embeddings import (
#      16     MultimodalEmbeddingsObject,
#      17     MultimodalInputRequest,
#    (...)     22     MultimodalInputSegmentVideoURL,
#      23 )
#
# File ~/Desktop/development/anthropic/anthropic-claude-api/.venv/lib/python3.14/site-packages/voyageai/object/__init__.py:3
#       1 from voyageai.object.contextualized_embeddings import ContextualizedEmbeddingsObject
#       2 from voyageai.object.embeddings import EmbeddingsObject
# ----> 3 from voyageai.object.multimodal_embeddings import MultimodalEmbeddingsObject
#       4 from voyageai.object.reranking import RerankingObject
#       6 __all__ = [
#       7     "ContextualizedEmbeddingsObject",
#       8     "EmbeddingsObject",
#       9     "MultimodalEmbeddingsObject",
#      10     "RerankingObject",
#      11 ]
#
# File ~/Desktop/development/anthropic/anthropic-claude-api/.venv/lib/python3.14/site-packages/voyageai/object/multimodal_embeddings.py:89
#      85     class Config:
#      86         extra = Extra.forbid
# ---> 89 class MultimodalInput(BaseModel):
#      90     content: List[
#      91         Annotated[
#      92             Union[
#    (...)    100         ]
#     101     ] = Field(..., min_items=1)
#     104 class MultimodalInputRequest(BaseModel):
#
# File ~/Desktop/development/anthropic/anthropic-claude-api/.venv/lib/python3.14/site-packages/pydantic/v1/main.py:221, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     219 elif is_valid_field(var_name) and var_name not in annotations and can_be_changed:
#     220     validate_field_name(bases, var_name)
# --> 221     inferred = ModelField.infer(
#     222         name=var_name,
#     223         value=value,
#     224         annotation=annotations.get(var_name, Undefined),
#     225         class_validators=vg.get_validators(var_name),
#     226         config=config,
#     227     )
#     228     if var_name in fields:
#     229         if lenient_issubclass(inferred.type_, fields[var_name].type_):
#
# File ~/Desktop/development/anthropic/anthropic-claude-api/.venv/lib/python3.14/site-packages/pydantic/v1/fields.py:502, in ModelField.infer(cls, name, value, annotation, class_validators, config)
#     500 elif value is not Undefined:
#     501     required = False
# --> 502 annotation = get_annotation_from_field_info(annotation, field_info, name, config.validate_assignment)
#     504 return cls(
#     505     name=name,
#     506     type_=annotation,
#    (...)    513     field_info=field_info,
#     514 )
#
# File ~/Desktop/development/anthropic/anthropic-claude-api/.venv/lib/python3.14/site-packages/pydantic/v1/schema.py:1021, in get_annotation_from_field_info(annotation, field_info, field_name, validate_assignment)
#    1019 unused_constraints = constraints - used_constraints
#    1020 if unused_constraints:
# -> 1021     raise ValueError(
#    1022         f'On field "{field_name}" the following field constraints are set but not enforced: '
#    1023         f'{", ".join(unused_constraints)}. '
#    1024         f'\nFor more details see https://docs.pydantic.dev/usage/schema/#unenforced-field-constraints'
#    1025     )
#    1027 return annotation
#
# ValueError: On field "content" the following field constraints are set but not enforced: min_items.
# For more details see https://docs.pydantic.dev/usage/schema/#unenforced-field-constraints

# %%
# Chunk by section
import re


def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
# Embedding Generation
def generate_embedding(text, model="voyage-3-large", input_type="query"):
    result = client.embed([text], model=model, input_type=input_type)

    return result.embeddings[0]

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_section(text)

generate_embedding(chunks[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       2     text = f.read()
#       3
#       4 chunks = chunk_by_section(text)
#       5
# ----> 6 generate_embedding(chunks[0])
#
# Cell In[6], line 3, in generate_embedding(text, model, input_type)
#       2 def generate_embedding(text, model="voyage-3-large", input_type="query"):
# ----> 3     result = client.embed([text], model=model, input_type=input_type)
#       4
#       5     return result.embeddings[0]
#
# NameError: name 'client' is not defined
